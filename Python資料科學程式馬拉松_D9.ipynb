# %% [markdown]
# <a href="https://colab.research.google.com/github/jimmiychen/ML100Days/blob/main/Python%E8%B3%87%E6%96%99%E7%A7%91%E5%AD%B8%E7%A8%8B%E5%BC%8F%E9%A6%AC%E6%8B%89%E6%9D%BE_D9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1.請建立類似提供結果的 DataFrame：**
# ![圖片1.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd
df1=pd.DataFrame(
        {
    'Apples':[30],
    'Bananas':[21]
}
)

print(df1)
print("\n")

df2=pd.DataFrame(
        {
    'Apples':[35,21],
    'Bananas':[41,34],
},

index=['2017 Sales','2018 Sales']  #index需在字典外面
)

print(df2)
# Out:
#    Apples  Bananas
# 0      30       21
#
#
#             Apples  Bananas
# 2017 Sales      35       41
# 2018 Sales      21       34

# %% [markdown]
# # **2.請問如果現在有一個 DataFrame 如下，請問資料在 Python 中可能長怎樣？**
# ![圖片2.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd
df=pd.DataFrame(
       {
    'city':['Austin','Dallas','Austin','Dallas'],
    'visitor':[139,237,326,456],
    'weekday':['Sun','Sun','Mon','Mon']
}
)
print(df)
# Out:
#      city  visitor weekday
# 0  Austin      139     Sun
# 1  Dallas      237     Sun
# 2  Austin      326     Mon
# 3  Dallas      456     Mon

# %% [markdown]
# # **3.假設你想知道每個 weekday 的平均 visitor 數量，可以怎麼做？**

# %%
print(df.iat[0,1])
print(df.iat[1,1])

print(df.iat[2,1])
print(df.iat[3,1])

sun=0
mon=0
for i in range(4):
  if i<=1:
    sun=sun+df.iat[i,1]
  else:
    mon=mon+df.iat[i,1]
print(sun)
print(mon)

print("\n")
print("Sun 平均:",sun/2)
print("Mon 平均:",mon/2)
# Out:
# 139
# 237
# 326
# 456
# 376
# 782
#
#
# Sun 平均: 188.0
# Mon 平均: 391.0
